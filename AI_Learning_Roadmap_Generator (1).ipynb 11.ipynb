# %%
# !pip install -q -U google-genai gradio

# %%
from google import genai
import os

client = genai.Client(
    api_key=os.environ.get("GEMINI_API_KEY")
)

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-omni-1.1-flash
# models/gemini-3.5-transcribe
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/gemini-3.8-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/lyria-3.5
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/antigravity-preview-09-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-3.5-transcribe-live
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
# models/gemini-3.8-live
# models/gemini-3.8-live-extended-thinking
# models/gemini-robotics-er-2-streaming-preview
# models/gemini-3.5-live-translate-preview
# models/lyria-realtime-exp

# %%
def generate_roadmap(domain, level, learning_time, hours_per_week):

    prompt = f"""
You are an expert learning roadmap designer.

Create a personalized learning roadmap for a student.

Learning Domain:
{domain}

Current Skill Level:
{level}

Available Learning Time:
{learning_time}

Hours Available Per Week:
{hours_per_week}

Create a realistic and practical roadmap.

Include:

1. Learning Goal
2. Prerequisites
3. Learning Roadmap
4. Weekly Topics
5. Practice Exercises
6. Projects
7. Tools and Technologies
8. Portfolio Projects
9. Final Skills

Adjust the difficulty according to the student's
current skill level.

Adjust the amount of content according to the
available learning time.

Do not overload the learner.

Use clear Markdown formatting.
"""

    try:

        response = client.interactions.create(
            model="gemini-3.5-flash-lite",
            input=prompt
        )

        return response.output_text

    except Exception as e:

        return f"❌ Error: {str(e)}"

# %%
roadmap = generate_roadmap(
    domain="Python",
    level="Beginner",
    learning_time="3 months",
    hours_per_week=10
)

print(roadmap)
# Out:
# # Personalized Learning Roadmap: Python for Beginners
#
# * **Learning Domain:** Python Programming
# * **Current Skill Level:** Beginner (No prior coding experience required)
# * **Available Learning Time:** 3 Months (12 Weeks)
# * **Time Commitment:** 10 Hours Per Week (Total: ~120 Hours)
#
# ---
#
# ## 1. Learning Goal
# By the end of this 3-month roadmap, you will be able to write clean, efficient Python code, understand fundamental programming concepts (Object-Oriented Programming, data structures, error handling), interact with files and APIs, and build functional command-line and beginner-level graphical applications.
#
# ---
#
# ## 2. Prerequisites
# * A computer (Windows, macOS, or Linux).
# * A stable internet connection to download software and search documentation.
# * Problem-solving mindset and patience (debugging is part of the process!).
#
# ---
#
# ## 3. Learning Roadmap Overview
# * **Month 1 (Weeks 1–4):** Python Basics & Core Control Flow
# * **Month 2 (Weeks 5–8):** Data Structures, Functions, & File Handling
# * **Month 3 (Weeks 9–12):** Object-Oriented Programming (OOP), APIs, & Final Project
#
# ---
#
# ## 4. Weekly Topics & 5. Practice Exercises
#
# ### **Month 1: Python Basics & Core Control Flow**
#
# #### **Week 1: Introduction, Variables, and Data Types**
# * **Topics:** Installing Python and VS Code; variables; integers, floats, strings, and booleans; basic arithmetic operations; type casting (`int()`, `str()`, etc.).
# * **Practice Exercise:** Write a script that asks the user for their name and birth year, calculates their approximate age, and prints a greeting message.
#
# #### **Week 2: Conditional Statements**
# * **Topics:** Comparison operators (`>`, `<`, `==`, etc.); logical operators (`and`, `or`, `not`); `if`, `elif`, and `else` statements.
# * **Practice Exercise:** Build a simple grading system that takes a numerical score (0-100) and prints the corresponding letter grade (A, B, C, D, F).
#
# #### **Week 3: Loops (for & while)**
# * **Topics:** `for` loops and iteration over ranges/strings; `while` loops; `break` and `continue` statements.
# * **Practice Exercise:** Create a Number Guessing Game where the computer picks a random number between 1 and 20, and the user has to guess it, with hints ("Too high" / "Too low").
#
# #### **Week 4: Month 1 Review & Mini-Project**
# * **Topics:** Reviewing syntax, debugging common errors, organizing small scripts.
# * **Practice Exercise:** Combine variables, conditionals, and loops into a Text-Based Calculator that runs continuously until the user types "quit".
#
# ---
#
# ### **Month 2: Data Structures, Functions, & File Handling**
#
# #### **Week 5: Lists and Tuples**
# * **Topics:** Creating lists; indexing and slicing; common list methods (`append`, `pop`, `sort`, `len`); introduction to immutable tuples.
# * **Practice Exercise:** Build a digital "Shopping List" manager where users can add, remove, and view items in their list.
#
# #### **Week 6: Dictionaries and Sets**
# * **Topics:** Key-value pairs in dictionaries; dictionary methods (`keys()`, `values()`, `get()`); introduction to unique elements in sets.
# * **Practice Exercise:** Create a simple English-to-Spanish translation dictionary where users can look up words or add new words.
#
# #### **Week 7: Functions and Scope**
# * **Topics:** Defining functions (`def`); parameters and arguments; return values; local vs. global variables.
# * **Practice Exercise:** Refactor your Month 1 Calculator project so that each math operation (+, -, *, /) is handled by its own dedicated function.
#
# #### **Week 8: Working with Files & Error Handling**
# * **Topics:** Reading and writing text files (`open()`, `read()`, `write()`, `with` blocks); basic error handling using `try`, `except`, and `finally`.
# * **Practice Exercise:** Modify the Shopping List manager so that it saves the list to a `.txt` file before closing and loads it automatically when reopened.
#
# ---
#
# ### **Month 3: OOP, APIs, & Final Project**
#
# #### **Week 9: Object-Oriented Programming (OOP) - Part 1**
# * **Topics:** Introduction to OOP; classes and objects; attributes; the `__init__` constructor method.
# * **Practice Exercise:** Create a `BankAccount` class with attributes like `owner` and `balance`, and methods to `deposit()` and `withdraw()`.
#
# #### **Week 10: Object-Oriented Programming (OOP) - Part 2**
# * **Topics:** Class methods; inheritance (child and parent classes); method overriding.
# * **Practice Exercise:** Create a base `Animal` class, and two child classes (`Dog` and `Cat`) that inherit from it and override a `make_sound()` method.
#
# #### **Week 11: Introduction to APIs & External Libraries**
# * **Topics:** What is an API? Using the `requests` library to fetch data from a public API (e.g., weather or joke APIs); parsing JSON data.
# * **Practice Exercise:** Write a Python script that fetches a random joke from a public API and prints it to the console.
#
# #### **Week 12: Final Capstone Project & Wrap-up**
# * **Topics:** Putting everything together; writing clean documentation (README); code cleanup.
# * **Practice Exercise:** Complete your Capstone Project (details below).
#
# ---
#
# ## 6. Projects (Milestones)
# 1. **End of Month 1:** *Text-Based Calculator* (Consolidates variables, conditionals, and loops).
# 2. **End of Month 2:** *File-Backed Todo List* (Consolidates data structures, functions, and file I/O).
# 3. **End of Month 3 (Portfolio Project):** *Weather Forecasting App* (Consolidates OOP, error handling, and API integration).
#
# ---
#
# ## 7. Tools and Technologies
# * **Language:** Python 3.x
# * **Code Editor:** Visual Studio Code (VS Code)
# * **Essential Python Libraries:** `requests` (for API calls), `random` and `json` (built-in modules).
# * **Version Control (Optional/Bonus):** Git and GitHub for saving code versions.
#
# ---
#
# ## 8. Portfolio Projects
# Upon completing this roadmap, you will have the following ready to showcase on GitHub:
# * **Python Todo/Shopping CLI App:** Demonstrates data structure management and local data persistence (file reading/writing).
# * **Weather/Joke API Fetcher:** Demonstrates external data handling, JSON parsing, and error handling.
# * **OOP Banking System:** Demonstrates clean object-oriented architecture, encapsulation, and class inheritance.
#
# ---
#
# ## 9. Final Skills
# By completing this 10-hour-per-week roadmap, you will acquire:
# * Strong foundational knowledge of Python syntax and core logic.
# * Ability to structure code cleanly using functions and classes (OOP).
# * Practical experience handling errors and debugging.
# * Ability to read and write data to files and interact with web APIs.
# * Confidence to tackle intermediate Python topics (like data science, web development, or automation) next.

# %%
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎓 AI Learning Roadmap Generator

        Create a personalized learning roadmap with AI.
        """
    )

    domain = gr.Textbox(
        label="📚 Learning Domain",
        placeholder="e.g. Python, Web Development, Data Science"
    )

    level = gr.Dropdown(
        choices=[
            "Beginner",
            "Intermediate",
            "Advanced"
        ],
        value="Beginner",
        label="📊 Skill Level"
    )

    learning_time = gr.Textbox(
        label="⏳ Time to Learn",
        placeholder="e.g. 3 months, 6 months, 1 year"
    )

    hours_per_week = gr.Slider(
        minimum=1,
        maximum=40,
        value=10,
        step=1,
        label="🕐 Hours Per Week"
    )

    generate_button = gr.Button(
        "🚀 Generate Roadmap"
    )

    output = gr.Markdown(
        label="Your AI Roadmap"
    )

    generate_button.click(
        fn=generate_roadmap,
        inputs=[
            domain,
            level,
            learning_time,
            hours_per_week
        ],
        outputs=output
    )

# %%
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://eecee21b104c9a6a82.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://eecee21b104c9a6a82.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎓 AI Learning Roadmap Generator

        ### Create a personalized learning roadmap with AI
        """
    )

    domain = gr.Textbox(
        label="📚 Learning Domain",
        placeholder="e.g. Python, Web Development, Data Science"
    )

    level = gr.Dropdown(
        choices=[
            "Beginner",
            "Intermediate",
            "Advanced"
        ],
        value="Beginner",
        label="📊 Skill Level"
    )

    learning_time = gr.Textbox(
        label="⏳ Time to Learn",
        placeholder="e.g. 3 months, 6 months, 1 year"
    )

    hours_per_week = gr.Slider(
        minimum=1,
        maximum=40,
        value=10,
        step=1,
        label="🕐 Hours Per Week"
    )

    generate_button = gr.Button(
        "🚀 Generate Roadmap"
    )

    output = gr.Markdown()

    # Connect button to the function
    generate_button.click(
        fn=generate_roadmap,
        inputs=[
            domain,
            level,
            learning_time,
            hours_per_week
        ],
        outputs=output
    )

# Launch the app
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ac38ad5c81ebb469b9.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ac38ad5c81ebb469b9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
